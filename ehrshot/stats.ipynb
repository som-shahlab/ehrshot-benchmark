# %%
import pandas as pd
from tqdm import tqdm
import os
from typing import List, Dict

# %%
# Same ordering as paper
task_2_name: Dict[str, str] = {
    # Operational outcomes
    'guo_los': 'Long LOS',
    'guo_readmission': '30-Day Readmission',
    'guo_icu': 'ICU Admission',
    # Anticipating lab test results
    'lab_thrombocytopenia': 'Thrombocytopenia',
    'lab_hyperkalemia': 'Hyperkalemia',
    'lab_hypoglycemia': 'Hypoglycemia',
    'lab_hyponatremia': 'Hyponatremia',
    'lab_anemia': 'Anemia',
    # Assignment of new diagnoses
    'new_hypertension': 'Hypertension',
    'new_hyperlipidemia': 'Hyperlipidemia',
    'new_pancan': 'Pancreatic Cancer',
    'new_celiac': 'Celiac',
    'new_lupus': 'Lupus',
    'new_acutemi' : 'Acute MI',
    # Anticipating chest x-ray findings
    'chexpert' : 'Chest X-Ray',
}

task_2_value_type: Dict[str, str] = {
    'new_pancan': 'boolean',
    'new_celiac': 'boolean',
    'new_lupus': 'boolean',
    'new_acutemi' : 'boolean',
    'new_hypertension': 'boolean',
    'new_hyperlipidemia': 'boolean',
    'guo_los': 'boolean',
    'guo_readmission': 'boolean',
    'guo_icu': 'boolean',
    'lab_thrombocytopenia': 'multiclass',
    'lab_hyperkalemia': 'multiclass',
    'lab_hypoglycemia': 'multiclass',
    'lab_hyponatremia': 'multiclass',
    'lab_anemia': 'multiclass',
    'chexpert' : 'multilabel',
}

# %%
path_to_data_csv = '../EHRSHOT_ASSETS/data/ehrshot.csv'
path_to_labels_dir = '../EHRSHOT_ASSETS/benchmark/'
path_to_splits_csv = '../EHRSHOT_ASSETS/splits/person_id_map.csv'

# %% [markdown]
# # Overall Stats

# %%
df_dataset = pd.read_csv(path_to_data_csv)
df_split = pd.read_csv(path_to_splits_csv)
# Out:
# /var/folders/h4/1v78m5xj34d9hlchb2rsvndh0000gn/T/ipykernel_34327/1359692343.py:1: DtypeWarning: Columns (3,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_dataset = pd.read_csv(path_to_data_csv)

# %%
print("# of events:", df_dataset.shape[0])
print("# of patients:", df_dataset['patient_id'].nunique())
print("# of visits:", df_dataset['visit_id'].nunique())
print("# of train patients", df_split[df_split['split'] == 'train']['omop_person_id'].nunique())
print("# of val patients", df_split[df_split['split'] == 'val']['omop_person_id'].nunique())
print("# of test patients", df_split[df_split['split'] == 'test']['omop_person_id'].nunique())
# Out:
# # of events: 41661637
# # of patients: 6739
# # of visits: 921499
# # of train patients 2295
# # of val patients 2232
# # of test patients 2212

# %% [markdown]
# # Label Stats

# %%
df_labels = pd.read_csv(os.path.join(path_to_labels_dir, 'all_labels.csv'))

# %%
print("# of labels:", df_labels.shape[0])
# Out:
# # of labels: 406379

# %%
results = {
    'train' : [],
    'test' : [],
    'val' : [],
    'all' : []
}
for task, task_name in tqdm(task_2_name.items()):
    path_to_task_csv: str = f"{path_to_labels_dir}{task}/labeled_patients.csv"
    if not os.path.exists(path_to_task_csv):
        print(f"Skipping {task_name} @ {path_to_task_csv}")
        continue
    df = pd.read_csv(path_to_task_csv)
    value_type = task_2_value_type[task]
    if task_2_value_type[task] == "boolean":
        df['is_positive_label'] = df["value"]
    elif task_2_value_type[task] == "multiclass":
        df['is_positive_label'] = df["value"] > 0
    elif task_2_value_type[task] == "multilabel":
        df['is_positive_label'] = df["value"] != 8192
    else:
        print(f"Skipping {task_name}")
        continue
    
    # Splits
    for split in ['train', 'test', 'val']:
        df_ = df[df['patient_id'].isin(df_split[df_split['split'] == split]['omop_person_id'])]
        results[split].append({
            'task' : task,
            'task_name' : task_name,
            'n_patients' : df_['patient_id'].nunique(),
            'n_positive_patients' : df_.groupby('patient_id')['is_positive_label'].max().sum(),
            'n_labels' : df_.shape[0],
            'n_positive_labels' : df_['is_positive_label'].sum(),
        })
    
    # All
    results['all'].append({
        'task' : task,
        'task_name' : task_name,
        'n_patients' : df['patient_id'].nunique(),
        'n_positive_patients' : df.groupby('patient_id')['is_positive_label'].max().sum(),
        'n_labels' : df.shape[0],
        'n_positive_labels' : df['is_positive_label'].sum(),
    })

for key in results.keys():
    results[key] = pd.DataFrame(results[key])
    results[key]['n_negative_labels'] = results[key]['n_labels'] - results[key]['n_positive_labels']
    results[key]['n_negative_patients'] = results[key]['n_patients'] - results[key]['n_positive_patients']
    results[key]['label_prevalence'] = results[key]['n_positive_labels'] / results[key]['n_labels']
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 19.30it/s]

# %%
results['all']
# Out:
#                     task           task_name  n_patients  n_positive_patients  \
# 0                guo_los            Long LOS        3855                 1271
# 1        guo_readmission  30-Day Readmission        3718                  474
# 2                guo_icu       ICU Admission        3617                  266
# 3   lab_thrombocytopenia    Thrombocytopenia        6063                 2566
# 4       lab_hyperkalemia        Hyperkalemia        5931                 1289
# 5       lab_hypoglycemia        Hypoglycemia        5974                 1379
# 6       lab_hyponatremia        Hyponatremia        5921                 3692
# 7             lab_anemia              Anemia        6086                 4271
# 8       new_hypertension        Hypertension        2328                  386
# 9     new_hyperlipidemia      Hyperlipidemia        2650                  410
# 10            new_pancan   Pancreatic Cancer        3864                  214
# 11            new_celiac              Celiac        3899                   69
# 12             new_lupus               Lupus        3864                  122
# 13           new_acutemi            Acute MI        3834                  357
# 14              chexpert         Chest X-Ray        1045                  996
#
#     n_labels  n_positive_labels  n_negative_labels  n_negative_patients  \
# 0       6995               1767               5228                 2584
# 1       7003                911               6092                 3244
# 2       6491                290               6201                 3351
# 3     179618              59718             119900                 3497
# 4     200170               4769             195401                 4642
# 5     318164               4721             313443                 4595
# 6     212837              60708             152129                 2229
# 7     184880             127496              57384                 1815
# 8       3764                516               3248                 1942
# 9       4442                566               3876                 2240
# 10      7011                264               6747                 3650
# 11      7129                 94               7035                 3830
# 12      7038                157               6881                 3742
# 13      6837                464               6373                 3477
# 14     26275              17203               9072                   49
#
#     label_prevalence
# 0           0.252609
# 1           0.130087
# 2           0.044677
# 3           0.332472
# 4           0.023825
# 5           0.014838
# 6           0.285232
# 7           0.689615
# 8           0.137088
# 9           0.127420
# 10          0.037655
# 11          0.013186
# 12          0.022307
# 13          0.067866
# 14          0.654729

# %%
# Train
results['train']
# Out:
#                     task           task_name  n_patients  n_positive_patients  \
# 0                guo_los            Long LOS        1377                  464
# 1        guo_readmission  30-Day Readmission        1337                  164
# 2                guo_icu       ICU Admission        1306                  107
# 3   lab_thrombocytopenia    Thrombocytopenia        2084                  906
# 4       lab_hyperkalemia        Hyperkalemia        2038                  456
# 5       lab_hypoglycemia        Hypoglycemia        2054                  511
# 6       lab_hyponatremia        Hyponatremia        2035                 1294
# 7             lab_anemia              Anemia        2092                 1484
# 8       new_hypertension        Hypertension         792                  129
# 9     new_hyperlipidemia      Hyperlipidemia         923                  137
# 10            new_pancan   Pancreatic Cancer        1376                  128
# 11            new_celiac              Celiac        1392                   48
# 12             new_lupus               Lupus        1377                   79
# 13           new_acutemi            Acute MI        1365                  130
# 14              chexpert         Chest X-Ray         251                  237
#
#     n_labels  n_positive_labels  n_negative_labels  n_negative_patients  \
# 0       2569                681               1888                  913
# 1       2608                370               2238                 1173
# 2       2402                113               2289                 1199
# 3      68776              22714              46062                 1178
# 4      76349               1829              74520                 1582
# 5     122108               1904             120204                 1543
# 6      81336              23877              57459                  741
# 7      70501              49028              21473                  608
# 8       1259                182               1077                  663
# 9       1684                205               1479                  786
# 10      2576                155               2421                 1248
# 11      2623                 62               2561                 1344
# 12      2570                104               2466                 1298
# 13      2534                175               2359                 1235
# 14      7481               4771               2710                   14
#
#     label_prevalence
# 0           0.265084
# 1           0.141871
# 2           0.047044
# 3           0.330261
# 4           0.023956
# 5           0.015593
# 6           0.293560
# 7           0.695423
# 8           0.144559
# 9           0.121734
# 10          0.060171
# 11          0.023637
# 12          0.040467
# 13          0.069061
# 14          0.637749

# %%
# Val
results['val']
# Out:
#                     task           task_name  n_patients  n_positive_patients  \
# 0                guo_los            Long LOS        1240                  395
# 1        guo_readmission  30-Day Readmission        1191                  159
# 2                guo_icu       ICU Admission        1157                   84
# 3   lab_thrombocytopenia    Thrombocytopenia        1981                  807
# 4       lab_hyperkalemia        Hyperkalemia        1935                  428
# 5       lab_hypoglycemia        Hypoglycemia        1950                  433
# 6       lab_hyponatremia        Hyponatremia        1930                 1174
# 7             lab_anemia              Anemia        1992                 1379
# 8       new_hypertension        Hypertension         781                  128
# 9     new_hyperlipidemia      Hyperlipidemia         863                  140
# 10            new_pancan   Pancreatic Cancer        1242                   46
# 11            new_celiac              Celiac        1252                    8
# 12             new_lupus               Lupus        1238                   24
# 13           new_acutemi            Acute MI        1234                  112
# 14              chexpert         Chest X-Ray         395                  378
#
#     n_labels  n_positive_labels  n_negative_labels  n_negative_patients  \
# 0       2231                534               1697                  845
# 1       2206                281               1925                 1032
# 2       2052                 92               1960                 1073
# 3      54504              17867              36637                 1174
# 4      60168               1386              58782                 1507
# 5      95488               1449              94039                 1517
# 6      64473              17557              46916                  756
# 7      56224              38498              17726                  613
# 8       1247                175               1072                  653
# 9       1441                189               1252                  723
# 10      2215                 53               2162                 1196
# 11      2284                 11               2273                 1244
# 12      2225                 33               2192                 1214
# 13      2176                145               2031                 1122
# 14      9366               6032               3334                   17
#
#     label_prevalence
# 0           0.239355
# 1           0.127380
# 2           0.044834
# 3           0.327811
# 4           0.023036
# 5           0.015175
# 6           0.272316
# 7           0.684725
# 8           0.140337
# 9           0.131159
# 10          0.023928
# 11          0.004816
# 12          0.014831
# 13          0.066636
# 14          0.644032

# %%
# Test
results['test']
# Out:
#                     task           task_name  n_patients  n_positive_patients  \
# 0                guo_los            Long LOS        1238                  412
# 1        guo_readmission  30-Day Readmission        1190                  151
# 2                guo_icu       ICU Admission        1154                   75
# 3   lab_thrombocytopenia    Thrombocytopenia        1998                  853
# 4       lab_hyperkalemia        Hyperkalemia        1958                  405
# 5       lab_hypoglycemia        Hypoglycemia        1970                  435
# 6       lab_hyponatremia        Hyponatremia        1956                 1224
# 7             lab_anemia              Anemia        2002                 1408
# 8       new_hypertension        Hypertension         755                  129
# 9     new_hyperlipidemia      Hyperlipidemia         864                  133
# 10            new_pancan   Pancreatic Cancer        1246                   40
# 11            new_celiac              Celiac        1255                   13
# 12             new_lupus               Lupus        1249                   19
# 13           new_acutemi            Acute MI        1235                  115
# 14              chexpert         Chest X-Ray         399                  381
#
#     n_labels  n_positive_labels  n_negative_labels  n_negative_patients  \
# 0       2195                552               1643                  826
# 1       2189                260               1929                 1039
# 2       2037                 85               1952                 1079
# 3      56338              19137              37201                 1145
# 4      63653               1554              62099                 1553
# 5     100568               1368              99200                 1535
# 6      67028              19274              47754                  732
# 7      58155              39970              18185                  594
# 8       1258                159               1099                  626
# 9       1317                172               1145                  731
# 10      2220                 56               2164                 1206
# 11      2222                 21               2201                 1242
# 12      2243                 20               2223                 1230
# 13      2127                144               1983                 1120
# 14      9428               6400               3028                   18
#
#     label_prevalence
# 0           0.251481
# 1           0.118776
# 2           0.041728
# 3           0.339682
# 4           0.024414
# 5           0.013603
# 6           0.287551
# 7           0.687301
# 8           0.126391
# 9           0.130600
# 10          0.025225
# 11          0.009451
# 12          0.008917
# 13          0.067701
# 14          0.678829
