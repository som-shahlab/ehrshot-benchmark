# %%
import pandas as pd
from tqdm import tqdm
import os
from typing import List, Dict

# %%
# Same ordering as paper
task_2_name: Dict[str, str] = {
    # Operational outcomes
    'guo_los': 'Long LOS',
    'guo_readmission': '30-Day Readmission',
    'guo_icu': 'ICU Admission',
    # Anticipating lab test results
    'lab_thrombocytopenia': 'Thrombocytopenia',
    'lab_hyperkalemia': 'Hyperkalemia',
    'lab_hypoglycemia': 'Hypoglycemia',
    'lab_hyponatremia': 'Hyponatremia',
    'lab_anemia': 'Anemia',
    # Assignment of new diagnoses
    'new_hypertension': 'Hypertension',
    'new_hyperlipidemia': 'Hyperlipidemia',
    'new_pancan': 'Pancreatic Cancer',
    'new_celiac': 'Celiac',
    'new_lupus': 'Lupus',
    'new_acutemi' : 'Acute MI',
    # Anticipating chest x-ray findings
    'chexpert' : 'Chest X-Ray',
}

task_2_value_type: Dict[str, str] = {
    'new_pancan': 'boolean',
    'new_celiac': 'boolean',
    'new_lupus': 'boolean',
    'new_acutemi' : 'boolean',
    'new_hypertension': 'boolean',
    'new_hyperlipidemia': 'boolean',
    'guo_los': 'boolean',
    'guo_readmission': 'boolean',
    'guo_icu': 'boolean',
    'lab_thrombocytopenia': 'multiclass',
    'lab_hyperkalemia': 'multiclass',
    'lab_hypoglycemia': 'multiclass',
    'lab_hyponatremia': 'multiclass',
    'lab_anemia': 'multiclass',
    'chexpert' : 'multilabel',
}

# %%
path_to_data_csv = '../EHRSHOT_ASSETS/data/ehrshot.csv'
path_to_labels_dir = '../EHRSHOT_ASSETS/benchmark/'
path_to_splits_csv = '../EHRSHOT_ASSETS/splits/person_id_map.csv'

# %% [markdown]
# # Overall Stats

# %%
df_dataset = pd.read_csv(path_to_data_csv)
df_split = pd.read_csv(path_to_splits_csv)
# Out:
# /var/folders/h4/1v78m5xj34d9hlchb2rsvndh0000gn/T/ipykernel_9475/1359692343.py:1: DtypeWarning: Columns (3,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_dataset = pd.read_csv(path_to_data_csv)

# %%
print("# of events:", df_dataset.shape[0])
print("# of patients:", df_dataset['patient_id'].nunique())
print("# of visits:", df_dataset['visit_id'].nunique())
print("# of train patients", df_split[df_split['split'] == 'train']['omop_person_id'].nunique())
print("# of val patients", df_split[df_split['split'] == 'val']['omop_person_id'].nunique())
print("# of test patients", df_split[df_split['split'] == 'test']['omop_person_id'].nunique())
# Out:
# # of events: 41661637
# # of patients: 6739
# # of visits: 921499
# # of train patients 2295
# # of val patients 2232
# # of test patients 2212

# %% [markdown]
# # Label Stats

# %%
df_labels = pd.read_csv(os.path.join(path_to_labels_dir, 'all_labels.csv'))

# %%
print("# of labels:", df_labels.shape[0])
# Out:
# # of labels: 406379

# %%
results = {
    'train' : [],
    'test' : [],
    'val' : [],
    'all' : []
}
for task, task_name in tqdm(task_2_name.items()):
    path_to_task_csv: str = f"{path_to_labels_dir}{task}/labeled_patients.csv"
    if not os.path.exists(path_to_task_csv):
        print(f"Skipping {task_name} @ {path_to_task_csv}")
        continue
    df = pd.read_csv(path_to_task_csv)
    value_type = task_2_value_type[task]
    if task_2_value_type[task] == "boolean":
        df['is_positive_label'] = df["value"]
    elif task_2_value_type[task] == "multiclass":
        df['is_positive_label'] = df["value"] > 0
    elif task_2_value_type[task] == "multilabel":
        df['is_positive_label'] = df["value"] != 8192
    else:
        print(f"Skipping {task_name}")
        continue
    
    # Splits
    for split in ['train', 'test', 'val']:
        df_ = df[df['patient_id'].isin(df_split[df_split['split'] == split]['omop_person_id'])]
        results[split].append({
            'task' : task,
            'task_name' : task_name,
            'n_patients' : df_['patient_id'].nunique(),
            'n_positive_patients' : df_.groupby('patient_id')['is_positive_label'].max().sum(),
            'n_labels' : df_.shape[0],
            'n_positive_labels' : df_['is_positive_label'].sum(),
        })
    
    # All
    results['all'].append({
        'task' : task,
        'task_name' : task_name,
        'n_patients' : df['patient_id'].nunique(),
        'n_positive_patients' : df.groupby('patient_id')['is_positive_label'].max().sum(),
        'n_labels' : df.shape[0],
        'n_positive_labels' : df['is_positive_label'].sum(),
    })

for key in results.keys():
    results[key] = pd.DataFrame(results[key])
    results[key]['n_negative_labels'] = results[key]['n_labels'] - results[key]['n_positive_labels']
    results[key]['n_negative_patients'] = results[key]['n_patients'] - results[key]['n_positive_patients']
    results[key]['label_prevalence'] = results[key]['n_positive_labels'] / results[key]['n_labels']
    results[key] = results[key][['task_name', 'n_patients', 'n_positive_patients', 'n_negative_patients', 'n_labels', 'n_positive_labels', 'n_negative_labels', 'label_prevalence']]
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 21.94it/s]

# %%
results['all']
# Out:
#              task_name  n_patients  n_positive_patients  n_negative_patients  \
# 0             Long LOS        3855                 1271                 2584
# 1   30-Day Readmission        3718                  474                 3244
# 2        ICU Admission        3617                  266                 3351
# 3     Thrombocytopenia        6063                 2566                 3497
# 4         Hyperkalemia        5931                 1289                 4642
# 5         Hypoglycemia        5974                 1379                 4595
# 6         Hyponatremia        5921                 3692                 2229
# 7               Anemia        6086                 4271                 1815
# 8         Hypertension        2328                  386                 1942
# 9       Hyperlipidemia        2650                  410                 2240
# 10   Pancreatic Cancer        3864                  214                 3650
# 11              Celiac        3899                   69                 3830
# 12               Lupus        3864                  122                 3742
# 13            Acute MI        3834                  357                 3477
# 14         Chest X-Ray        1045                  996                   49
#
#     n_labels  n_positive_labels  n_negative_labels  label_prevalence
# 0       6995               1767               5228          0.252609
# 1       7003                911               6092          0.130087
# 2       6491                290               6201          0.044677
# 3     179618              59718             119900          0.332472
# 4     200170               4769             195401          0.023825
# 5     318164               4721             313443          0.014838
# 6     212837              60708             152129          0.285232
# 7     184880             127496              57384          0.689615
# 8       3764                516               3248          0.137088
# 9       4442                566               3876          0.127420
# 10      7011                264               6747          0.037655
# 11      7129                 94               7035          0.013186
# 12      7038                157               6881          0.022307
# 13      6837                464               6373          0.067866
# 14     26275              17203               9072          0.654729

# %%
# Train
results['train']
# Out:
#              task_name  n_patients  n_positive_patients  n_negative_patients  \
# 0             Long LOS        1377                  464                  913
# 1   30-Day Readmission        1337                  164                 1173
# 2        ICU Admission        1306                  107                 1199
# 3     Thrombocytopenia        2084                  906                 1178
# 4         Hyperkalemia        2038                  456                 1582
# 5         Hypoglycemia        2054                  511                 1543
# 6         Hyponatremia        2035                 1294                  741
# 7               Anemia        2092                 1484                  608
# 8         Hypertension         792                  129                  663
# 9       Hyperlipidemia         923                  137                  786
# 10   Pancreatic Cancer        1376                  128                 1248
# 11              Celiac        1392                   48                 1344
# 12               Lupus        1377                   79                 1298
# 13            Acute MI        1365                  130                 1235
# 14         Chest X-Ray         251                  237                   14
#
#     n_labels  n_positive_labels  n_negative_labels  label_prevalence
# 0       2569                681               1888          0.265084
# 1       2608                370               2238          0.141871
# 2       2402                113               2289          0.047044
# 3      68776              22714              46062          0.330261
# 4      76349               1829              74520          0.023956
# 5     122108               1904             120204          0.015593
# 6      81336              23877              57459          0.293560
# 7      70501              49028              21473          0.695423
# 8       1259                182               1077          0.144559
# 9       1684                205               1479          0.121734
# 10      2576                155               2421          0.060171
# 11      2623                 62               2561          0.023637
# 12      2570                104               2466          0.040467
# 13      2534                175               2359          0.069061
# 14      7481               4771               2710          0.637749

# %%
# Val
results['val']
# Out:
#              task_name  n_patients  n_positive_patients  n_negative_patients  \
# 0             Long LOS        1240                  395                  845
# 1   30-Day Readmission        1191                  159                 1032
# 2        ICU Admission        1157                   84                 1073
# 3     Thrombocytopenia        1981                  807                 1174
# 4         Hyperkalemia        1935                  428                 1507
# 5         Hypoglycemia        1950                  433                 1517
# 6         Hyponatremia        1930                 1174                  756
# 7               Anemia        1992                 1379                  613
# 8         Hypertension         781                  128                  653
# 9       Hyperlipidemia         863                  140                  723
# 10   Pancreatic Cancer        1242                   46                 1196
# 11              Celiac        1252                    8                 1244
# 12               Lupus        1238                   24                 1214
# 13            Acute MI        1234                  112                 1122
# 14         Chest X-Ray         395                  378                   17
#
#     n_labels  n_positive_labels  n_negative_labels  label_prevalence
# 0       2231                534               1697          0.239355
# 1       2206                281               1925          0.127380
# 2       2052                 92               1960          0.044834
# 3      54504              17867              36637          0.327811
# 4      60168               1386              58782          0.023036
# 5      95488               1449              94039          0.015175
# 6      64473              17557              46916          0.272316
# 7      56224              38498              17726          0.684725
# 8       1247                175               1072          0.140337
# 9       1441                189               1252          0.131159
# 10      2215                 53               2162          0.023928
# 11      2284                 11               2273          0.004816
# 12      2225                 33               2192          0.014831
# 13      2176                145               2031          0.066636
# 14      9366               6032               3334          0.644032

# %%
# Test
results['test']
# Out:
#              task_name  n_patients  n_positive_patients  n_negative_patients  \
# 0             Long LOS        1238                  412                  826
# 1   30-Day Readmission        1190                  151                 1039
# 2        ICU Admission        1154                   75                 1079
# 3     Thrombocytopenia        1998                  853                 1145
# 4         Hyperkalemia        1958                  405                 1553
# 5         Hypoglycemia        1970                  435                 1535
# 6         Hyponatremia        1956                 1224                  732
# 7               Anemia        2002                 1408                  594
# 8         Hypertension         755                  129                  626
# 9       Hyperlipidemia         864                  133                  731
# 10   Pancreatic Cancer        1246                   40                 1206
# 11              Celiac        1255                   13                 1242
# 12               Lupus        1249                   19                 1230
# 13            Acute MI        1235                  115                 1120
# 14         Chest X-Ray         399                  381                   18
#
#     n_labels  n_positive_labels  n_negative_labels  label_prevalence
# 0       2195                552               1643          0.251481
# 1       2189                260               1929          0.118776
# 2       2037                 85               1952          0.041728
# 3      56338              19137              37201          0.339682
# 4      63653               1554              62099          0.024414
# 5     100568               1368              99200          0.013603
# 6      67028              19274              47754          0.287551
# 7      58155              39970              18185          0.687301
# 8       1258                159               1099          0.126391
# 9       1317                172               1145          0.130600
# 10      2220                 56               2164          0.025225
# 11      2222                 21               2201          0.009451
# 12      2243                 20               2223          0.008917
# 13      2127                144               1983          0.067701
# 14      9428               6400               3028          0.678829

# %%
print(results['all'].to_markdown(index=False))
# Out:
# | task_name          |   n_patients |   n_positive_patients |   n_negative_patients |   n_labels |   n_positive_labels |   n_negative_labels |   label_prevalence |
# |:-------------------|-------------:|----------------------:|----------------------:|-----------:|--------------------:|--------------------:|-------------------:|
# | Long LOS           |         3855 |                  1271 |                  2584 |       6995 |                1767 |                5228 |          0.252609  |
# | 30-Day Readmission |         3718 |                   474 |                  3244 |       7003 |                 911 |                6092 |          0.130087  |
# | ICU Admission      |         3617 |                   266 |                  3351 |       6491 |                 290 |                6201 |          0.0446772 |
# | Thrombocytopenia   |         6063 |                  2566 |                  3497 |     179618 |               59718 |              119900 |          0.332472  |
# | Hyperkalemia       |         5931 |                  1289 |                  4642 |     200170 |                4769 |              195401 |          0.0238247 |
# | Hypoglycemia       |         5974 |                  1379 |                  4595 |     318164 |                4721 |              313443 |          0.0148383 |
# | Hyponatremia       |         5921 |                  3692 |                  2229 |     212837 |               60708 |              152129 |          0.285232  |
# | Anemia             |         6086 |                  4271 |                  1815 |     184880 |              127496 |               57384 |          0.689615  |
# | Hypertension       |         2328 |                   386 |                  1942 |       3764 |                 516 |                3248 |          0.137088  |
# | Hyperlipidemia     |         2650 |                   410 |                  2240 |       4442 |                 566 |                3876 |          0.12742   |
# | Pancreatic Cancer  |         3864 |                   214 |                  3650 |       7011 |                 264 |                6747 |          0.0376551 |
# | Celiac             |         3899 |                    69 |                  3830 |       7129 |                  94 |                7035 |          0.0131856 |
# | Lupus              |         3864 |                   122 |                  3742 |       7038 |                 157 |                6881 |          0.0223075 |
# | Acute MI           |         3834 |                   357 |                  3477 |       6837 |                 464 |                6373 |          0.067866  |
# | Chest X-Ray        |         1045 |                   996 |                    49 |      26275 |               17203 |                9072 |          0.654729  |

# %%
print(results['train'].to_markdown(index=False))
# Out:
# | task_name          |   n_patients |   n_positive_patients |   n_negative_patients |   n_labels |   n_positive_labels |   n_negative_labels |   label_prevalence |
# |:-------------------|-------------:|----------------------:|----------------------:|-----------:|--------------------:|--------------------:|-------------------:|
# | Long LOS           |         1377 |                   464 |                   913 |       2569 |                 681 |                1888 |          0.265084  |
# | 30-Day Readmission |         1337 |                   164 |                  1173 |       2608 |                 370 |                2238 |          0.141871  |
# | ICU Admission      |         1306 |                   107 |                  1199 |       2402 |                 113 |                2289 |          0.0470441 |
# | Thrombocytopenia   |         2084 |                   906 |                  1178 |      68776 |               22714 |               46062 |          0.330261  |
# | Hyperkalemia       |         2038 |                   456 |                  1582 |      76349 |                1829 |               74520 |          0.0239558 |
# | Hypoglycemia       |         2054 |                   511 |                  1543 |     122108 |                1904 |              120204 |          0.0155928 |
# | Hyponatremia       |         2035 |                  1294 |                   741 |      81336 |               23877 |               57459 |          0.29356   |
# | Anemia             |         2092 |                  1484 |                   608 |      70501 |               49028 |               21473 |          0.695423  |
# | Hypertension       |          792 |                   129 |                   663 |       1259 |                 182 |                1077 |          0.144559  |
# | Hyperlipidemia     |          923 |                   137 |                   786 |       1684 |                 205 |                1479 |          0.121734  |
# | Pancreatic Cancer  |         1376 |                   128 |                  1248 |       2576 |                 155 |                2421 |          0.0601708 |
# | Celiac             |         1392 |                    48 |                  1344 |       2623 |                  62 |                2561 |          0.0236371 |
# | Lupus              |         1377 |                    79 |                  1298 |       2570 |                 104 |                2466 |          0.0404669 |
# | Acute MI           |         1365 |                   130 |                  1235 |       2534 |                 175 |                2359 |          0.0690608 |
# | Chest X-Ray        |          251 |                   237 |                    14 |       7481 |                4771 |                2710 |          0.637749  |

# %%
print(results['val'].to_markdown(index=False))
# Out:
# | task_name          |   n_patients |   n_positive_patients |   n_negative_patients |   n_labels |   n_positive_labels |   n_negative_labels |   label_prevalence |
# |:-------------------|-------------:|----------------------:|----------------------:|-----------:|--------------------:|--------------------:|-------------------:|
# | Long LOS           |         1240 |                   395 |                   845 |       2231 |                 534 |                1697 |         0.239355   |
# | 30-Day Readmission |         1191 |                   159 |                  1032 |       2206 |                 281 |                1925 |         0.12738    |
# | ICU Admission      |         1157 |                    84 |                  1073 |       2052 |                  92 |                1960 |         0.0448343  |
# | Thrombocytopenia   |         1981 |                   807 |                  1174 |      54504 |               17867 |               36637 |         0.327811   |
# | Hyperkalemia       |         1935 |                   428 |                  1507 |      60168 |                1386 |               58782 |         0.0230355  |
# | Hypoglycemia       |         1950 |                   433 |                  1517 |      95488 |                1449 |               94039 |         0.0151747  |
# | Hyponatremia       |         1930 |                  1174 |                   756 |      64473 |               17557 |               46916 |         0.272316   |
# | Anemia             |         1992 |                  1379 |                   613 |      56224 |               38498 |               17726 |         0.684725   |
# | Hypertension       |          781 |                   128 |                   653 |       1247 |                 175 |                1072 |         0.140337   |
# | Hyperlipidemia     |          863 |                   140 |                   723 |       1441 |                 189 |                1252 |         0.131159   |
# | Pancreatic Cancer  |         1242 |                    46 |                  1196 |       2215 |                  53 |                2162 |         0.0239278  |
# | Celiac             |         1252 |                     8 |                  1244 |       2284 |                  11 |                2273 |         0.00481611 |
# | Lupus              |         1238 |                    24 |                  1214 |       2225 |                  33 |                2192 |         0.0148315  |
# | Acute MI           |         1234 |                   112 |                  1122 |       2176 |                 145 |                2031 |         0.066636   |
# | Chest X-Ray        |          395 |                   378 |                    17 |       9366 |                6032 |                3334 |         0.644032   |

# %%
print(results['test'].to_markdown(index=False))
# Out:
# | task_name          |   n_patients |   n_positive_patients |   n_negative_patients |   n_labels |   n_positive_labels |   n_negative_labels |   label_prevalence |
# |:-------------------|-------------:|----------------------:|----------------------:|-----------:|--------------------:|--------------------:|-------------------:|
# | Long LOS           |         1238 |                   412 |                   826 |       2195 |                 552 |                1643 |         0.251481   |
# | 30-Day Readmission |         1190 |                   151 |                  1039 |       2189 |                 260 |                1929 |         0.118776   |
# | ICU Admission      |         1154 |                    75 |                  1079 |       2037 |                  85 |                1952 |         0.041728   |
# | Thrombocytopenia   |         1998 |                   853 |                  1145 |      56338 |               19137 |               37201 |         0.339682   |
# | Hyperkalemia       |         1958 |                   405 |                  1553 |      63653 |                1554 |               62099 |         0.0244136  |
# | Hypoglycemia       |         1970 |                   435 |                  1535 |     100568 |                1368 |               99200 |         0.0136027  |
# | Hyponatremia       |         1956 |                  1224 |                   732 |      67028 |               19274 |               47754 |         0.287551   |
# | Anemia             |         2002 |                  1408 |                   594 |      58155 |               39970 |               18185 |         0.687301   |
# | Hypertension       |          755 |                   129 |                   626 |       1258 |                 159 |                1099 |         0.126391   |
# | Hyperlipidemia     |          864 |                   133 |                   731 |       1317 |                 172 |                1145 |         0.1306     |
# | Pancreatic Cancer  |         1246 |                    40 |                  1206 |       2220 |                  56 |                2164 |         0.0252252  |
# | Celiac             |         1255 |                    13 |                  1242 |       2222 |                  21 |                2201 |         0.00945095 |
# | Lupus              |         1249 |                    19 |                  1230 |       2243 |                  20 |                2223 |         0.00891663 |
# | Acute MI           |         1235 |                   115 |                  1120 |       2127 |                 144 |                1983 |         0.067701   |
# | Chest X-Ray        |          399 |                   381 |                    18 |       9428 |                6400 |                3028 |         0.678829   |
